# %%
import GRNgene as oGRN
import numpy as np
AdjMatrice = np.array([[0, 1, 0],
                       [0, 0, -1],
                       [0, 0, 0]])
test = oGRN.GrnFromAdj(AdjMatrice)
print(test)
oGRN.plotGraph(test, True)
# Out:
# {'Graph': <networkx.classes.digraph.DiGraph object at 0x0000022EA40278E0>, 'genesNb': 3, 'autoRG': 0.0, 'duoRG': 0.0, 'AdjMatrice': array([[ 0,  1,  0],
#        [ 0,  0, -1],
#        [ 0,  0,  0]]), 'meanClustering': np.float64(0.0), 'subGraph': {'0-1-2': 'Cascade'}}

# %%
oGRN.simulationODEs(test, ["indirect"], (0,500),stochasticNoiseAmplitude=0,physicalNoiseAmplitude=0,dropOutRate=0)
oGRN.plotSim(test)

# %%
print(test["Coefficients"])
# Out:
# {'ProtsDeg': [np.float64(0.042240548457977756), np.float64(0.010958648294251028), np.float64(0.07514418503576488)], 'mRNAsDeg': [np.float64(0.1283315392353081), np.float64(0.25996572837740717), np.float64(0.282842712474619)], 'TranscriptionsRate': [1.08, 1.65, 3.32], 'TranslationsRate': [20.9, 111.16, 116.95], 'mRNAAvg': [12.88, 11.2, 21.02], 'ProtAvg': [6125.78, 43583.21, 41220.93]}

# %%
oGRN.plotProt(test)

# %%
Coeff = test["Coefficients"]
for i in range(test["genesNb"]):
    print(f"Prot{i} infini =", Coeff["TranslationsRate"][i]*Coeff["mRNAAvg"][i]/(Coeff["ProtAvg"][i]*Coeff["ProtsDeg"][i]))
# Out:
# Prot0 infini = 1.0403301979023638
# Prot1 infini = 2.6066958347619056
# Prot2 infini = 0.7936331012023918
